# %% [markdown]
# # Site Splitting
# ### Author: Max Sop
# The script in this notebook attempts to address one of the limitations of the route optimization program by splitting sites whose total weights (KGs) exceed a truck load capacity. Further development and adjustments would be required based on the Tech team suggestions. This should then be written as a Python script that sits on top of the route optimization program. So this is just a temporary solution. Ideally the LP optimizer needs to be rewritten in order to address all lingering issues such as cases where the solver doesn't return the expected results or to easily embed this program within the solver.
#
# For contextual or further understanding of the problem, please get in touch with Tobias Krause [tobias.krause@oneacrefund.org ]

# %%
#Load basic libraries
import pandas as pd

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
distance_df     = pd.read_excel('DistanceMatrix (2).xlsx')
client_input_df = pd.read_excel('Client Inputs.xlsx', sheet_name='Client Inputs')

# %%
client_input_grp = client_input_df.groupby(['SiteName','GroupName'])['TotalKgWeight'].agg(sum).reset_index(level=['SiteName',"GroupName"])

# %%
client_input_grp['SiteWeight'] = client_input_grp.groupby(['SiteName'])['TotalKgWeight'].transform(sum)
client_input_grp.sort_values(by=['SiteName' ,'TotalKgWeight'], ascending=True, inplace=True)
client_input_grp['GroupWeightRunningTotal'] = client_input_grp.groupby(['SiteName'])['TotalKgWeight'].transform(pd.Series.cumsum)

# %%
client_input_grp[client_input_grp['SiteName'] == 'Balek'].reset_index(drop=True)
# Out:
#    SiteName    GroupName  TotalKgWeight  SiteWeight  GroupWeightRunningTotal
# 0     Balek        Bidii        107.800    11797.28                  107.800
# 1     Balek    Cheptagum        108.700    11797.28                  216.500
# 2     Balek      Central        166.550    11797.28                  383.050
# 3     Balek        Pluto        182.550    11797.28                  565.600
# 4     Balek        kaple        197.250    11797.28                  762.850
# 5     Balek  kapchelogoi        217.600    11797.28                  980.450
# 6     Balek       Koshin        235.750    11797.28                 1216.200
# 7     Balek     Kabirget        237.500    11797.28                 1453.700
# 8     Balek      Tembwet        250.850    11797.28                 1704.550
# 9     Balek       Soingo        257.250    11797.28                 1961.800
# 10    Balek     Karorwet        263.050    11797.28                 2224.850
# 11    Balek      Kuskong        268.500    11797.28                 2493.350
# 12    Balek      Arorwet        269.750    11797.28                 2763.100
# 13    Balek    Benditaai        269.950    11797.28                 3033.050
# 14    Balek        Seast        290.650    11797.28                 3323.700
# 15    Balek     Mwangaza        319.400    11797.28                 3643.100
# 16    Balek       Testai        337.353    11797.28                 3980.453
# 17    Balek      Ogilgei        350.900    11797.28                 4331.353
# 18    Balek       Banana        371.550    11797.28                 4702.903
# 19    Balek        Rural        371.750    11797.28                 5074.653
# 20    Balek   Kibisorwet        386.750    11797.28                 5461.403
# 21    Balek      Kirenwo        412.800    11797.28                 5874.203
# 22    Balek     setkobor        417.300    11797.28                 6291.503
# 23    Balek  Kesogororet        436.003    11797.28                 6727.506
# 24    Balek        Koita        458.600    11797.28                 7186.106
# 25    Balek     Kolongei        605.306    11797.28                 7791.412
# 26    Balek     taabaita        651.453    11797.28                 8442.865
# 27    Balek       Temiek        675.003    11797.28                 9117.868
# 28    Balek       Sumeek        719.750    11797.28                 9837.618
# 29    Balek       Saptet        729.753    11797.28                10567.371
# 30    Balek     midpoint       1229.909    11797.28                11797.280

# %%
def loop_routine(weight, max_truck_size, df, lst, ind, site_name, i):
        truck_load = df['TotalKgWeight'][:ind].sum()
        lst.append({'Sites': site_name + '_' + str(i), 'GroupList': list(df['GroupName'][:ind]), 'TruckLoad': truck_load})
        df = df.iloc[ind:].reset_index(drop=True)
        df['GroupWeightRunningTotal'] = df['TotalKgWeight'].cumsum()
        return df

# %%
list(client_input_grp.SiteName.unique())
# Out:
# 'Balek'

# %%
def split_site_group(df=client_input_grp, max_truck_size=10000):
    lst = []
    site_names =list(client_input_grp.SiteName.unique())
    for site_name in site_names:
        df = client_input_grp.loc[client_input_grp['SiteName'] == site_name, ['SiteWeight', 'GroupName', 'GroupWeightRunningTotal', 'TotalKgWeight']].reset_index(drop=True)
        site_weight = df['SiteWeight'][0]
        if(site_weight > max_truck_size): 
            i = 1
            for ind, weight in enumerate(df['GroupWeightRunningTotal']):
                if(weight >= max_truck_size):
                    truck_load = df['TotalKgWeight'][:ind].sum()
                    if (truck_load == 0): break
                    lst.append({'Sites': site_name + '_' + str(i), 'GroupList': list(df['GroupName'][:ind]), 'TruckLoad': truck_load})
                    i+=1
                    df = df.iloc[ind:]
                    if(df.shape[0] == 1):
                        lst.append({'Sites': site_name + '_' + str(i), 'GroupList': list(df['GroupName']), 'TruckLoad': df['TotalKgWeight'].values[0]})
        else:
            lst.append({'Sites': site_name, 'GroupList': list(df['GroupName']), 'TruckLoad': site_weight}) 
    return pd.DataFrame(lst)

# %%
split_site_group()
# Out:
#                                             GroupList        Sites  TruckLoad
# 0   [Bidii, Cheptagum, Central, Pluto, kaple, kapc...      Balek_1   9837.618
# 1                                  [Saptet, midpoint]      Balek_2   1959.662
# 2   [ebenezer, Amani, Emityot, kerundut, SIRIKWA, ...   Chebilat_1   8764.580
# 3                                             [Canan]   Chebilat_2   1431.318
# 4   [Pondet, Ngetumio, Munantet, Tokjin, Sibayan, ...  Chebirbelek   6684.370
# 5   [Greatvision, star, Kiletien, Kopor, ronkos, b...    Chebole_1   9182.454
# 6             [revelation, Asis, Kapkoin, Kiburburen]    Chebole_2   3738.845
# 7   [Sachangwany, Kulwet, CHEPTAGUM, Kapmugeni, Ch...     Chebongi   8916.568
# 8   [Corner, kona, kolongei, Cheptangulgel, Chomny...    Chesilyot   5912.712
# 9   [KONDAMET, Mizizi, KOPTIGEI, Sigingit, Extreme...  Kapchepkoro   4517.606
# 10  [Kapkosigo, kolongei, Mwangaza, Boreito, longm...     Kapkelei   7574.674
# 11  [chamngaa, Builders, Kitoroch, shine, Amani, U...     Kapkuret   4040.503
# 12  [Chepkosiom, Mogonjet, Matasi, Tumbelion, chep...      Kaplong   4228.806
# 13  [Kipgargang, koyon, jubille, Koborbor, chebaib...       Kenene   8037.624
# 14  [Siryat, Chamgaa, Kalyet, Torokwet, sise, Shin...    Kiboson_1   9954.468
# 15  [Sita, Kware, Kiboson, Temik, Ngom, Mokoywet, ...    Kiboson_2   7272.932
# 16  [Umoja, Amani, upendo, macheket, Nenyoon, Chek...   Kiimawit_1   9094.866
# 17                                           [Uchuzi]   Kiimawit_2   1063.471
# 18  [cheboet, ebeneser, KUTUNYKWONY, KAPSABAA, gen...  Kinyelwet_1   9744.074
# 19  [kamureito, KIRAIT, kware, KIPKETII, Kapkawa, ...  Kinyelwet_2   9611.979
# 20  [Lenny star, kalwet, Brigtwood, Kona, chebkutb...      Kipajit   5304.159
# 21  [reberwet, Tach, Ovocado, Mirror, viewpoint, m...       Kiriba   7818.312
# 22  [Lelechwet, Baregeiywet, Mokoket, Plombe, Oria...     Koimiret   6886.930
# 23  [BORDER, Simbi, Ebenezer, KOKWON, NEHEMA, Mace...     Mabwaita   9767.080
# 24  [kokilgei, Chepkobor, uswet, gelengei, kolongo...     Makimeny   4792.656
# 25  [Dip, Wendietai, Seet, MAKWERE, flower, FAMICA...      Rongena   6781.806
# 26  [Kapboisio, Chemaluk, ndimo, Seetkobor, Saunee...     Sigorian   9941.045
# 27  [Sebetet, temik, Sukutek Group, Kimugul, Tumai...       Siroin   4970.424
# 28  [Kibagenge, Rehema, kechenet, Kiletien, Mwanga...      Yaganek   4894.645

# %%
split_sites =  split_site_group()

# %%
def transform_distance(distance_df=distance_df, split_sites=split_sites):
    
    distance_df.columns = [column.replace(' (SOT)', '') for column in distance_df.columns]
    distance_df['Drops'] = distance_df['Drops'].apply(lambda x: x.replace(' (SOT)', ''))
    distance_df.set_index('Drops', inplace=True)
    site_columns = [site.split('_')[0] for site in split_sites.Sites if '_' in site]
    distance_columns = [column for column in distance_df.columns]
    
    df_column = pd.DataFrame()
    df_row = pd.DataFrame()
    
    for column in distance_columns:
        if column not in site_columns:
            df_column[column] = distance_df[column]
        else:
            for i in range(1, 3):
                col_name = column + '_' + str(i)
                df_column[col_name] = distance_df[column] 

    df_column = df_column.transpose()
    
    for column in distance_columns:
        if column not in site_columns:
            df_row[column] = df_column[column]
        else:
            for i in range(1, 3):
                col_name = column + '_' + str(i)
                df_row[col_name] = df_column[column] 
                
    return df_row

# %%
transform_distance()
# Out:
#              Balek_1  Balek_2  Chebilat_1  Chebilat_2  Chebirbelek  Chebole_1  \
# Balek_1        0.000    0.000      18.489      18.489        6.706     17.232
# Balek_2        0.000    0.000      18.489      18.489        6.706     17.232
# Chebilat_1    18.489   18.489       0.000       0.000       25.195     20.814
# Chebilat_2    18.489   18.489       0.000       0.000       25.195     20.814
# Chebirbelek    6.706    6.706      25.195      25.195        0.000     14.030
# Chebole_1     17.232   17.232      20.814      20.814       14.030      0.000
# Chebole_2     17.232   17.232      20.814      20.814       14.030      0.000
# Chebongi      16.455   16.455       6.998       6.998       23.161     18.780
# Chesilyot      2.153    2.153      16.335      16.335        8.860     19.385
# Kapchepkoro   13.259   13.259       7.265       7.265       19.251     14.429
# Kapkelei      32.992   32.992      17.472      17.472       39.698     35.317
# Kapkuret      16.210   16.210      19.793      19.793       22.270     10.774
# Kaplong       11.691   11.691       7.712       7.712       18.397     13.102
# Kenene         3.584    3.584      22.073      22.073        3.122     10.908
# Kiboson_1     27.109   27.109      30.691      30.691       23.193     10.293
# Kiboson_2     27.109   27.109      30.691      30.691       23.193     10.293
# Kiimawit_1     5.706    5.706      18.261      18.261       11.766     15.916
# Kiimawit_2     5.706    5.706      18.261      18.261       11.766     15.916
# Kinyelwet_1   14.603   14.603      18.186      18.186       16.778      3.216
# Kinyelwet_2   14.603   14.603      18.186      18.186       16.778      3.216
# Kipajit       18.808   18.808       8.738       8.738       25.514     12.567
# Kiriba        40.944   40.944      44.527      44.527       37.028     24.180
# Koimeret      31.767   31.767      35.350      35.350       27.851     14.951
# Mabwaita      28.008   28.008      12.488      12.488       34.714     30.333
# Makimeny      25.198   25.198      28.780      28.780       21.282      8.382
# Rongena       24.621   24.621       9.101       9.101       31.327     26.946
# Sigorian      32.434   32.434      25.468      25.468       28.518     15.618
# Siroin         6.382    6.382      24.871      24.871        0.324     13.705
# Yaganek        9.909    9.909       9.959       9.959       15.969     11.147
# Nyansiongo    29.707   29.707      11.218      11.218       36.413     32.032
#
#              Chebole_2  Chebongi  Chesilyot  Kapchepkoro     ...      Kipajit  \
# Balek_1         17.232    16.455      2.153       13.191     ...       18.808
# Balek_2         17.232    16.455      2.153       13.191     ...       18.808
# Chebilat_1      20.814     6.998     16.335        9.280     ...        8.738
# Chebilat_2      20.814     6.998     16.335        9.280     ...        8.738
# Chebirbelek     14.030    23.161      8.860       19.251     ...       25.514
# Chebole_1        0.000    18.780     19.385       14.429     ...       12.567
# Chebole_2        0.000    18.780     19.385       14.429     ...       12.567
# Chebongi        18.780     0.000     14.302        7.246     ...        7.317
# Chesilyot       19.385    14.302      0.000       11.105     ...       16.655
# Kapchepkoro     14.429     5.231     11.105        0.000     ...        5.374
# Kapkelei        35.317    21.500     30.838       23.783     ...       18.725
# Kapkuret        10.774    17.759     18.364       13.408     ...        8.364
# Kaplong         13.102     5.678      9.538        1.568     ...        8.031
# Kenene          10.908    20.039      5.737       16.129     ...       22.392
# Kiboson_1       10.293    28.658     29.262       24.306     ...       22.444
# Kiboson_2       10.293    28.658     29.262       24.306     ...       22.444
# Kiimawit_1      15.916    16.227      7.859       11.876     ...       15.025
# Kiimawit_2      15.916    16.227      7.859       11.876     ...       15.025
# Kinyelwet_1      3.216    16.152     16.756       11.800     ...        9.938
# Kinyelwet_2      3.216    16.152     16.756       11.800     ...        9.938
# Kipajit         12.567     7.317     16.655        5.374     ...        0.000
# Kiriba          24.180    42.493     43.097       38.141     ...       36.279
# Koimeret        14.951    33.316     33.920       28.964     ...       27.102
# Mabwaita        30.333    16.517     25.854       18.799     ...       13.741
# Makimeny         8.382    26.746     27.351       22.395     ...       20.533
# Rongena         26.946    13.129     22.467       15.412     ...       10.354
# Sigorian        15.618    33.983     34.587       29.631     ...       26.721
# Siroin          13.705    22.837      8.535       18.927     ...       25.190
# Yaganek         11.147     7.925     11.784        3.574     ...       10.278
# Nyansiongo      32.032    18.216     27.553       20.498     ...       19.956
#
#              Kiriba  Koimeret  Mabwaita  Makimeny  Rongena  Sigorian  Siroin  \
# Balek_1      40.944    31.767    28.008    25.198   24.621    32.434   6.382
# Balek_2      40.944    31.767    28.008    25.198   24.621    32.434   6.382
# Chebilat_1   44.527    35.350    12.488    28.780    9.101    25.468  24.871
# Chebilat_2   44.527    35.350    12.488    28.780    9.101    25.468  24.871
# Chebirbelek  37.028    27.851    34.714    21.282   31.327    28.518   0.324
# Chebole_1    24.180    14.951    30.333     8.382   26.946    15.618  13.705
# Chebole_2    24.180    14.951    30.333     8.382   26.946    15.618  13.705
# Chebongi     42.493    33.316    16.517    26.746   13.129    33.983  22.837
# Chesilyot    43.097    33.920    25.854    27.351   22.467    34.587   8.535
# Kapchepkoro  38.141    28.964    16.784    22.395   13.396    29.631  18.927
# Kapkelei     27.764    17.694    12.185    15.232   10.165     7.996  39.373
# Kapkuret     34.486    25.309    17.927    18.740   15.019    10.561  21.946
# Kaplong      36.815    27.638    17.231    21.068   13.844    28.305  18.073
# Kenene       33.906    24.729    31.592    18.160   28.204    25.396   2.798
# Kiboson_1    17.484     7.414    21.522     1.911   17.033     4.562  22.869
# Kiboson_2    17.484     7.414    21.522     1.911   17.033     4.562  22.869
# Kiimawit_1   39.629    30.452    27.780    23.882   24.393    31.119  11.442
# Kiimawit_2   39.629    30.452    27.780    23.882   24.393    31.119  11.442
# Kinyelwet_1  26.929    17.752    27.705    11.182   24.317    18.419  16.454
# Kinyelwet_2  26.929    17.752    27.705    11.182   24.317    18.419  16.454
# Kipajit      36.279    27.102    13.741    20.533   10.354    26.721  25.190
# Kiriba        0.000    10.070    54.046    16.639   50.658    19.767  36.704
# Koimeret     10.070     0.000    29.879     6.569   25.390     9.698  27.527
# Mabwaita     54.046    30.108     0.000    38.299    5.182    20.410  34.390
# Makimeny     16.639     6.569    38.299     0.000   34.912     7.236  20.958
# Rongena      50.658    25.390     5.182    34.912    0.000    15.692  31.002
# Sigorian     19.767     9.698    20.182     7.236   15.692     0.000  28.194
# Siroin       36.704    27.527    34.390    20.958   31.002    28.194   0.000
# Yaganek      34.859    25.682    19.478    19.113   16.091    26.349  15.645
# Nyansiongo   55.744    46.567    23.706    39.998   20.319    36.686  36.089
#
#              Yaganek  Nyansiongo
# Balek_1        9.909      29.707
# Balek_2        9.909      29.707
# Chebilat_1     9.959      11.218
# Chebilat_2     9.959      11.218
# Chebirbelek   15.969      36.413
# Chebole_1     11.147      32.032
# Chebole_2     11.147      32.032
# Chebongi       7.925      18.216
# Chesilyot     11.784      27.553
# Kapchepkoro    3.574      18.483
# Kapkelei      24.462      28.690
# Kapkuret      10.126      31.011
# Kaplong        2.247      18.930
# Kenene        12.847      33.291
# Kiboson_1     21.024      41.909
# Kiboson_2     21.024      41.909
# Kiimawit_1     8.594      29.479
# Kiimawit_2     8.594      29.479
# Kinyelwet_1    8.518      29.403
# Kinyelwet_2    8.518      29.403
# Kipajit       10.278      19.956
# Kiriba        34.859      55.744
# Koimeret      25.682      46.567
# Mabwaita      19.478      23.706
# Makimeny      19.113      39.998
# Rongena       16.091      20.319
# Sigorian      26.349      36.686
# Siroin        15.645      36.089
# Yaganek        0.000      21.177
# Nyansiongo    21.177       0.000
#
# [30 rows x 30 columns]

# %%
# def split_site_group(df=client_input_grp, max_truck_size=5000):
#     lst = []
#     site_names = list(client_input_grp.SiteName.unique())
#     for site_name in site_names:
#         df = client_input_grp.loc[client_input_grp['SiteName'] == site_name, ['SiteWeight', 'GroupName', 'GroupWeightRunningTotal', 'TotalKgWeight']].reset_index(drop=True)
#         site_weight = df['SiteWeight'][0]
#         if(site_weight > max_truck_size): 
#             i = 1
#             for ind, weight in enumerate(df['GroupWeightRunningTotal']):
#                 if(weight >= max_truck_size):
#                     truck_load = df['TotalKgWeight'][:ind].sum()
#                     if (truck_load == 0): break
#                     lst.append({'Sites': site_name + '_' + str(i), 'GroupList': list(df['GroupName'][:ind]), 'TruckLoad': truck_load})
#                     i+=1
#                     df = df.iloc[ind:]
#                     if(df.shape[0] == 1):
#                         lst.append({'Sites': site_name + '_' + str(i), 'GroupList': list(df['GroupName']), 'TruckLoad': df['TotalKgWeight'].values[0]})
#         else:
#             lst.append({'Sites': site_name, 'GroupList': list(df['GroupName']), 'TruckLoad': site_weight}) 
#     return pd.DataFrame(lst)
